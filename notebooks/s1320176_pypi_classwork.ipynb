# %% [markdown]
# # SE07 Class Work: Setting up your own PyPI repository
#
# Student ID: s1320176
#
# GitHub repository: https://github.com/awashimakentaro/s1320176_learn
#
# PyPI package: https://pypi.org/project/s1320176-learn/
#
# TestPyPI package: https://test.pypi.org/project/s1320176-learn/

# %% [markdown]
# ## Package structure
#
# The repository contains `s1320176_learn/`, `notebooks/`, and Python package files. The package has `statistics` and `visualization` subpackages with `itemFequencies.py` and `heatMap.py`. The `setup.py` file includes `pami` as a dependency.

# %%
# !pip install s1320176_learn
# Out:
# pec
#     Found existing installation: fsspec 2025.10.0
#     Uninstalling fsspec-2025.10.0:
#       Successfully uninstalled fsspec-2025.10.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.60.2
#     Uninstalling fonttools-4.60.2:
#       Successfully uninstalled fonttools-4.60.2
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/awashima/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: cramjam
#     Found existing installation: cramjam 2.11.0
#     Uninstalling cramjam-2.11.0:
#       Successfully uninstalled cramjam-2.11.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.0
#     Uninstalling contourpy-1.3.0:
#       Successfully uninstalled contourpy-1.3.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.5
#     Uninstalling aiohttp-3.13.5:
#       Successfully uninstalled aiohttp-3.13.5
#   Attempting uninstall: validators
#     Found existing installation: validators 0.35.0
#     Uninstalling validators-0.35.0:
#       Successfully uninstalled validators-0.35.0
#   Attempting uninstall: sphinx-rtd-theme
#     Found existing installation: sphinx-rtd-theme 3.1.0
#     Uninstalling sphinx-rtd-theme-3.1.0:
#       Successfully uninstalled sphinx-rtd-theme-3.1.0
#   Attempting uninstall: resource
#     Found existing installation: Resource 0.2.1
#     Uninstalling Resource-0.2.1:
#       Successfully uninstalled Resource-0.2.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.2.2
#     Uninstalling psutil-7.2.2:
#       Successfully uninstalled psutil-7.2.2
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.9.0
#     Uninstalling plotly-6.9.0:
#       Successfully uninstalled plotly-6.9.0
#   WARNING: The script plotly_get_chrome is installed in '/Users/awashima/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.4
#     Uninstalling matplotlib-3.9.4:
#       Successfully uninstalled matplotlib-3.9.4
#   Attempting uninstall: fastparquet
#     Found existing installation: fastparquet 2024.11.0
#     Uninstalling fastparquet-2024.11.0:
#       Successfully uninstalled fastparquet-2024.11.0
#   Attempting uninstall: discord.py
#     Found existing installation: discord-py 2.7.1
#     Uninstalling discord-py-2.7.1:
#       Successfully uninstalled discord-py-2.7.1
#   Attempting uninstall: deprecated
#     Found existing installation: deprecated 1.3.1
#     Uninstalling deprecated-1.3.1:
#       Successfully uninstalled deprecated-1.3.1
#   Attempting uninstall: pami
#     Found existing installation: pami 2026.7.24.1
#     Uninstalling pami-2026.7.24.1:
#       Successfully uninstalled pami-2026.7.24.1
#   Attempting uninstall: s1320176-learn
#     Found existing installation: s1320176-learn 0.1.0
#     Uninstalling s1320176-learn-0.1.0:
#       Successfully uninstalled s1320176-learn-0.1.0
# Successfully installed Jinja2-3.1.6 JsonForm-0.0.2 JsonSir-0.0.2 MarkupSafe-3.0.3 Pillow-11.3.0 PyYAML-6.0.3 Pygments-2.20.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 alabaster-0.7.16 async-timeout-5.0.1 attrs-26.1.0 babel-2.18.0 certifi-2026.7.22 charset-normalizer-3.4.9 contourpy-1.3.0 cramjam-2.11.0 cycler-0.12.1 deprecated-1.3.1 discord.py-2.7.1 docutils-0.21.2 fastparquet-2024.11.0 fonttools-4.60.2 frozenlist-1.8.0 fsspec-2025.10.0 idna-3.18 imagesize-1.5.0 importlib-metadata-8.7.1 importlib-resources-6.5.2 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 kiwisolver-1.4.7 matplotlib-3.9.4 multidict-6.7.1 narwhals-2.21.0 networkx-3.2.1 numpy-2.0.2 packaging-26.2 pami-2026.7.24.1 pandas-2.3.3 plotly-6.9.0 propcache-0.4.1 psutil-7.2.2 pyparsing-3.3.2 python-dateutil-2.9.0.post0 python-easyconfig-0.1.7 pytz-2026.3.post1 referencing-0.36.2 requests-2.32.5 resource-0.2.1 rpds-py-0.27.1 s1320176-learn-0.1.0 six-1.17.0 snowballstemmer-3.1.1 sphinx-7.4.7 sphinx-rtd-theme-3.1.0 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 tomli-2.4.1 typing-extensions-4.16.0 tzdata-2026.3 urllib3-2.6.3 validators-0.35.0 wrapt-2.3.0 yarl-1.22.0 zipp-3.23.1
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip show s1320176_learn
# Out:
# Name: s1320176_learn
# Version: 0.1.0
# Summary: SE07 class work package for PyPI repository practice
# Home-page:
# Author: Kentaro Awashima
# Author-email:
# License:
# Location: /Users/awashima/Library/Python/3.9/lib/python/site-packages
# Requires: pami
# Required-by:

# %% [markdown]
# # SE07 Class Work: Setting up your own PyPI repository
#
# Student ID: s1320176
#
# Repository: https://github.com/awashimakentaro/s1320176_learn

# %% [markdown]
# ## Package structure
#
# The repository contains `s1320176_learn/`, `notebooks/`, and Python package files. The package has `statistics` and `visualization` subpackages with `itemFequencies.py` and `heatMap.py`. The `setup.py` file includes `pami` as a dependency.

# %%
# !pip install s1320176_learn
# Out:
# This is the command required after publishing the package to PyPI. TestPyPI/PyPI upload requires an API token, so the repository install below was used for local verification before final PyPI publication.

# %%
# !pip install git+https://github.com/awashimakentaro/s1320176_learn.git
# Out:
# ion: async-timeout 5.0.1
#     Uninstalling async-timeout-5.0.1:
#       Successfully uninstalled async-timeout-5.0.1
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.4.0
#     Uninstalling aiosignal-1.4.0:
#       Successfully uninstalled aiosignal-1.4.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.6.1
#     Uninstalling aiohappyeyeballs-2.6.1:
#       Successfully uninstalled aiohappyeyeballs-2.6.1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.3
#     Uninstalling wrapt-1.17.3:
#       Successfully uninstalled wrapt-1.17.3
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.5.2
#     Uninstalling importlib-resources-6.5.2:
# ...

# %%
# !pip show s1320176_learn
# Out:
# Name: s1320176-learn
# Version: 0.1.0
# Summary: SE07 class work package for PyPI repository practice
# Home-page: UNKNOWN
# Author: Kentaro Awashima
# Author-email:
# License: UNKNOWN
# Location: /Users/awashima/Library/Python/3.9/lib/python/site-packages
# Requires: pami
# Required-by:
